# %%
from transformers.utils import logging
logging.set_verbosity_error()

# %% [markdown]
# <h2> Transformer Pipeline </h2>

# %% [markdown]
# ![image.png](attachment:1a49ca00-e930-48b3-a769-2830a9be64f0.png)

# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation", model="distilgpt2")

generator("In this article about HuggingFace transformers, we",
    max_length=30,
    num_return_sequences=2)
# Out:
# [{'generated_text': 'In this article about HuggingFace transformers, we’re getting rid of this feature\n\nWe have changed HypeCon to handle that'},
#  {'generated_text': 'In this article about HuggingFace transformers, we asked you about how you can make this a very simple thing if you know where to get rid'}]
